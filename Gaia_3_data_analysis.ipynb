# %% [markdown]
# <a href="https://colab.research.google.com/github/vibhuti5/Space-O-Analytics/blob/main/Gaia_3_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
# !pip install wget

import numpy as np 
import pandas as pd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np 
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d9dff9c1-efa6-4329-b6f8-cd8a8d60281d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d9dff9c1-efa6-4329-b6f8-cd8a8d60281d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['dataset.csv']))

# %%
df2
# Out:
#                   source_id  mh_gspphot  distance_gspphot  radius_gspphot  \
# 0       1892971994938385152     -0.2297         1913.2518          0.6903
# 1       1892971994938390912     -1.1103         1414.8071          0.4954
# 2       1892971999234781312      0.0661         1411.8239          0.7323
# 3       1892972098017629696     -0.9274         1215.6301          0.5737
# 4       1892972102313998080     -0.7981         1557.3232          0.6925
# ...                     ...         ...               ...             ...
# 147631  1897959173524272896      0.0041         1814.6660          0.7479
# 147632  1897959173524280704      0.0436         1189.6232          0.6318
# 147633  1897959207884022912     -0.6622         2112.5496          0.8272
# 147634  1897959212180118400     -0.4128         1479.3003          1.4229
# 147635  1897959349618945280     -0.0758         1979.1002          3.8875
#
#         vsini_esphs  radius_flame  lum_flame  mass_flame  age_flame  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
df2.shape
# Out:
# (147636, 17)

# %%
plt.style.use('ggplot')


transparency = 0.2
size = 3

plt.grid()
plt.scatter(np.log10(df2.teff_gspphot),np.log10(df2.lum_flame),s=size,edgecolors='none',alpha=transparency)
plt.xlim(np.log10(15000),np.log10(2000))
plt.ylim(10,-10)
plt.gca().invert_xaxis()
plt.title("Hertzsprung-Russell Diagram")
plt.ylabel("log Luminosity")
plt.xlabel("log T")
# Out:
# Text(0.5, 0, 'log T')
